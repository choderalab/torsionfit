# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import simtk.openmm as mm
from torsionfit import TorsionScanSet as ScanSet
import torsionfit.TorsionFitModel as Model
from torsionfit import sqlite_plus
from pymc import MCMC
from parmed.charmm import CharmmParameterSet
from torsionfit import plots
from matplotlib.backends.backend_pdf import PdfPages
import numpy as np
# Out:
# /Users/chayastern/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
param = CharmmParameterSet('../../data/charmm_ff/top_all36_cgenff.rtf',
                           '../../data/charmm_ff/par_all36_cgenff.prm')
structure = '../structure/butane.psf'
scan = '../torsion_scans/DFT_b3lyp/butane_scan_b3lyp_360.log'

# %%
# Calculate full MM energy
butane_scan = ScanSet.parse_psi4(scan, structure)
butane_scan.compute_energy(param)

# %%
# Set all Torsion K's to 0

param.dihedral_types[('CG331', 'CG321', 'CG321', 'CG331')][1].phi_k=0
param.dihedral_types[('CG331', 'CG321', 'CG321', 'CG331')][0].phi_k=0
param.dihedral_types[('HGA3', 'CG331', 'CG321', 'HGA2')][0].phi_k=0
param.dihedral_types[('HGA2', 'CG321', 'CG331', 'HGA3')][0].phi_k=0
param.dihedral_types[('HGA3', 'CG331', 'CG321', 'CG321')][0].phi_k=0
param.dihedral_types[('CG321', 'CG321', 'CG331', 'HGA3')][0].phi_k=0
param.dihedral_types[('HGA2', 'CG321', 'CG321', 'HGA2')][0].phi_k=0
param.dihedral_types[('CG331', 'CG321', 'CG321', 'HGA2')][0].phi_k=0

# %%
# Now calculate MM energy without Dihedrals

butane_scan_no_dih = ScanSet.parse_psi4(scan, structure)
butane_scan_no_dih.compute_energy(param)

# %%
# Turn off everything besides dihedrals
structure_no_charge = '../structure/butane_charge_off.psf'
param_5 = CharmmParameterSet('../param/par_all36_cgenff.prm', '../param/top_all36_cgenff.rtf')

param_5.bond_types[('CG331', 'CG321')].k=0
param_5.bond_types[('CG321', 'CG321')].k=0
param_5.bond_types[('CG331', 'HGA3')].k=0
param_5.bond_types[('CG321', 'HGA2')].k=0
param_5.angle_types[('CG331', 'CG321', 'CG321')].k=0
param_5.angle_types[('HGA3', 'CG331', 'CG321')].k=0
param_5.angle_types[('HGA2', 'CG321', 'HGA2')].k=0
param_5.angle_types[('CG331', 'CG321', 'HGA2')].k=0
param_5.angle_types[('HGA3', 'CG331', 'HGA3')].k=0
param_5.angle_types[('HGA2', 'CG321', 'CG321')].k=0

scan_dih = ScanSet.parse_psi4(scan, structure_no_charge)
scan_dih.compute_energy(param_5)

# %%
plt.plot(butane_scan.steps, butane_scan.qm_energy, '.', color='Purple')
plt.plot(butane_scan.steps, butane_scan.qm_energy, color='Purple', label='DFT')
plt.plot(butane_scan.steps, butane_scan.mm_energy, '.', color='Red')
plt.plot(butane_scan.steps, butane_scan.mm_energy, color='Red', label='MM')
plt.plot(butane_scan.steps, butane_scan_no_dih.mm_energy, '.', color='orange')
plt.plot(butane_scan.steps, butane_scan_no_dih.mm_energy, color='orange', label='no Dih')
plt.plot(butane_scan.steps, scan_dih.mm_energy, '.', color='Blue')
plt.plot(butane_scan.steps, scan_dih.mm_energy, color='Blue', label='Dih')
plt.plot(butane_scan.steps, butane_scan_no_dih.delta_energy, '.', color='green')
plt.plot(butane_scan.steps, butane_scan_no_dih.delta_energy, color='green', label='Diff')


plt.xlabel('Dihedral Angle (Degrees)')
plt.ylabel('Relative Energy (KJ/mol)')

plt.title('Energy Contributions')
plt.legend(prop={'size':7})
plt.savefig('Torsion_scan_energy_contribution.pdf')

# %%
# Model and sample. The code was modified to fit the difference potential. 

platform = mm.Platform.getPlatformByName('Reference')

model = Model.TorsionFitModelEliminatePhase(param, butane_scan_no_dih, platform=platform, decouple_n=True,
                                            param_to_opt=[('CG331', 'CG321', 'CG321', 'CG331')])

sampler = MCMC(model.pymc_parameters, db=sqlite_plus, dbname='diff_pot.db', verbose=5)

# %%
plt.plot(butane_scan.steps, butane_scan_no_dih.mm_energy, '.', color='orange')
plt.plot(butane_scan.steps, butane_scan_no_dih.mm_energy, color='orange', label='no Dih')

plt.plot(butane_scan.steps, butane_scan_no_dih.delta_energy, '.', color='green')
plt.plot(butane_scan.steps, butane_scan_no_dih.delta_energy, color='green', label='Diff')

plt.plot(butane_scan_no_dih.steps, sampler.qm_fit.value, label='qm_fit_value')


plt.xlabel('Dihedral Angle (Degrees)')
plt.ylabel('Relative Energy (KJ/mol)')

plt.title('Energy Contributions')
plt.legend(prop={'size':7})
#plt.savefig('Torsion_scan_energy_contribution.pdf')

# %%
# Model and sample. The code was modified to fit the difference potential. 

platform = mm.Platform.getPlatformByName('Reference')

model = Model.TorsionFitModelEliminatePhase(param, butane_scan_no_dih, platform=platform, decouple_n=True,
                                            param_to_opt=[('CG331', 'CG321', 'CG321', 'CG331')])

sampler = MCMC(model.pymc_parameters, db=sqlite_plus, dbname='diff_pot.db', verbose=5)
sampler.sample(1000)
# Out:
# Assigning step method Metropolis to stochastic CG331_CG321_CG321_CG331_4_K
# Assigning step method Metropolis to stochastic CG331_CG321_CG321_CG331_6_K
# Assigning step method Metropolis to stochastic CG331_CG321_CG321_CG331_3_K
# Assigning step method Metropolis to stochastic log_sigma
# Assigning step method DiscreteMetropolis to stochastic CG331_CG321_CG321_CG331_multiplicity_bitstring
# Assigning step method Metropolis to stochastic BUTA1_offset
# Assigning step method Metropolis to stochastic CG331_CG321_CG321_CG331_2_K
# Assigning step method Metropolis to stochastic CG331_CG321_CG321_CG331_1_K
#  [-----------------100%-----------------] 1000 of 1000 complete in 52.6 sec

# %%
plt.plot(sampler.trace('mm_energy')[0], label='Initial MM (without dih)')
plt.plot(sampler.trace('mm_energy')[-1], '.', color='green', label='Fit')
plt.plot(sampler.qm_fit.value, color='red', label='difference potential')
plt.legend(prop={'size': 7})
plt.title('Energy fit')
plt.xlabel('Dihedral angle (Degrees)')
plt.ylabel('Energy (KJ/mol)')
plt.savefig('Energy_fit_no_mult.pdf')

# %%
plt.plot(np.exp(sampler.trace('log_sigma')[:]), label='sigma')
plt.xlabel('samples')
plt.ylabel('KJ/mol')
plt.title('Sigma')
plt.savefig('sigma_no_mult.pdf')

# %%
plt.title("CG331 CG321 CG331 CG321")

plt.subplot(3, 2, 1)
plt.hist(sampler.trace('CG331_CG321_CG321_CG331_1_K')[:], bins=30, label='1')
plt.axvline(0, color='r', linewidth=3)
plt.legend()
plt.ylabel('P(K)')
plt.title("CG331 CG321 CG331 CG321")

plt.subplot(3, 2, 3)
plt.hist(sampler.trace('CG331_CG321_CG321_CG331_2_K')[:], bins=30, label='2')
plt.axvline(0.038, color='r')
plt.legend()
plt.ylabel('P(K)')

plt.subplot(3, 2, 5)
plt.hist(sampler.trace('CG331_CG321_CG321_CG331_3_K')[:], bins=30, label='3')
plt.axvline(0, color='r', linewidth=3)
plt.legend()
plt.ylabel('P(K)')
plt.xlabel('Force constant (KJ/mol)')

plt.subplot(3, 2, 2)
plt.hist(sampler.trace('CG331_CG321_CG321_CG331_4_K')[:], bins=30, label='4')
plt.title("CG331 CG321 CG331 CG321")
plt.axvline(0, color='r')
plt.legend()

plt.subplot(3, 2, 4)
plt.hist(sampler.trace('CG331_CG321_CG321_CG331_6_K')[:], bins=30, label='6')
plt.axvline(0.032, color='r')
plt.legend()
plt.xlabel('Force constant (KJ/mol)')

plt.savefig('parameter_hist_no_mult.pdf')

# %%
plots.trace_no_phase('CG331_CG321_CG321_CG331', sampler, markersize=1.0)

# %%
plt.hist(sampler.trace('CG331_CG321_CG321_CG331_1_K')[:], bins=50, label='1')
plt.legend()

# %%
plt.hist(sampler.trace('CG331_CG321_CG321_CG331_2_K')[:], bins=50, label='2')
plt.legend()

# %%
plt.hist(sampler.trace('CG331_CG321_CG321_CG331_3_K')[:], bins=50, label='3')
plt.legend()

# %%
plt.hist(sampler.trace('CG331_CG321_CG321_CG331_4_K')[:], bins=50, label='4')
plt.legend()

# %%
plt.hist(sampler.trace('CG331_CG321_CG321_CG331_6_K')[:], bins=50, label='6')
plt.legend()

# %%
plt.plot(sampler.trace('BUTA1_offset')[:])
