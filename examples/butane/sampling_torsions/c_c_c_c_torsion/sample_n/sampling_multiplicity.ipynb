# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import simtk.openmm as mm
from torsionfit import TorsionScanSet as ScanSet
import torsionfit.TorsionFitModel as Model
from torsionfit import sqlite_plus
from pymc import MCMC
from parmed.charmm import CharmmParameterSet
from torsionfit import plots
from matplotlib.backends.backend_pdf import PdfPages
# Out:
# /Users/chayastern/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
param_to_opt=[('CG331', 'CG321', 'CG321', 'CG331')]
param = CharmmParameterSet('../data/charmm_ff/top_all36_cgenff.rtf', '../data/charmm_ff/par_all36_cgenff.prm')
structure = 'structure/butane.psf'
scan = 'MP2_torsion_scan/'
# Print initial guess
print param.dihedral_types[param_to_opt[0]]

# Create a butane scan with torsions on (to compare for difference potential)
butane_scan = ScanSet.parse_psi4_out(scan, structure)
butane_scan.compute_energy(param)
optimized = butane_scan.remove_nonoptimized()
optimized.compute_energy(param)

# Turn off torsion
param.dihedral_types[('CG331', 'CG321', 'CG321', 'CG331')][1].phi_k=0
param.dihedral_types[('CG331', 'CG321', 'CG321', 'CG331')][0].phi_k=0

# Create butane scan with torsions off
optimized_0 = butane_scan.remove_nonoptimized()
optimized_0.compute_energy(param)
# Out:
# <DihedralTypes [<DihedralType; phi_k=0.038, per=2, phase=0.000,  scee=1.000, scnb=1.000>, <DihedralType; phi_k=0.032, per=6, phase=180.000,  scee=1.000, scnb=1.000>]>
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/0/butane_0.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/10/butane_10.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# Warning: Optimizer failed for /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/10/butane_10.out2
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/20/butane_20.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/30/butane_30.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/40/butane_40.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/50/butane_50.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/60/butane_60.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/70/butane_70.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/80/butane_80.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/90/butane_90.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/100/butane_100.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/110/butane_110.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/120/butane_120.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/130/butane_130.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/140/butane_140.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/150/butane_150.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/160/butane_160.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/170/butane_170.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/180/butane_180.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/190/butane_190.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/200/butane_200.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/210/butane_210.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/220/butane_220.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/230/butane_230.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/240/butane_240.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/250/butane_250.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/260/butane_260.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/270/butane_270.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/280/butane_280.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/290/butane_290.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/300/butane_300.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/310/butane_310.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/320/butane_320.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/330/butane_330.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/340/butane_340.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/350/butane_350.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~
# [Psi /Users/chayastern/src/ChayaSt/Torsions/examples/butane/MP2_torsion_scan/360/butane_360.out2 WARNING] In logfileparser.py, line 467, line not all dashes as expected: --------------------------------------------------------------------------------------------- ~

# %%
plt.plot(optimized.steps, optimized.qm_energy, 'k.', label='QM')
plt.plot(optimized.steps, optimized.mm_energy, '.', label='MM')
plt.xlabel('Dihedral Angles (Degrees)')
plt.ylabel('Relative Energy (KJ/mol)')
plt.legend()

# %%
plt.plot(optimized_0.steps, optimized_0.delta_energy-min(optimized_0.delta_energy), label='Torsion off')
plt.plot(optimized.steps, optimized.delta_energy-min(optimized.delta_energy), label='Torsion on')
plt.legend()
plt.xlabel('Dihedral Angle (Degrees)')
plt.ylabel('Relative Energy (KJ/mol)')
plt.title('Butane Difference potential')

# %%
platform = mm.Platform.getPlatformByName('Reference')
model = Model.TorsionFitModelEliminatePhase(param, optimized, platform=platform, 
                                            param_to_opt=param_to_opt)
sampler = MCMC(model.pymc_parameters, db=sqlite_plus, dbname='butane_n.database', verbose=5)

# %%
sampler.sample(100000)
# Out:
# Assigning step method Metropolis to stochastic BUTA1_offset
# Assigning step method Metropolis to stochastic CG331_CG321_CG321_CG331_6_K
# Assigning step method DiscreteMetropolis to stochastic CG331_CG321_CG321_CG331_multiplicity_bitstring
# Assigning step method Metropolis to stochastic CG331_CG321_CG321_CG331_1_K
# Assigning step method Metropolis to stochastic log_sigma
# Assigning step method Metropolis to stochastic CG331_CG321_CG321_CG331_2_K
# Assigning step method Metropolis to stochastic CG331_CG321_CG321_CG331_3_K
# Assigning step method Metropolis to stochastic CG331_CG321_CG321_CG331_4_K
#  [-----------------100%-----------------] 100000 of 100000 complete in 7141.3 sec

# %%
import seaborn
plt.plot(optimized.mm_energy, 'ro', label='QM energy')
plt.plot(optimized.mm_energy, color='r')
plt.plot(sampler.trace('mm_energy')[0], 'b.', label='Initial energy')
plt.plot(sampler.trace('mm_energy')[-1], 'k.', label='MM fit')

seaborn.tsplot(sampler.trace('mm_energy')[:])
plt.legend()
plt.xlabel('Dihedral Angle')
plt.ylabel('Relative Energy (KJ/mol)')
plt.title('Butane Energy Fit')
plt.savefig('sample_n/Energy_fit_n.pdf')

# %%
plots.marg_mult(model, sampler, 100000)

# %%
db = sqlite_plus.load('butane_n_init_0.database')
multiplicities = ['1', '2', '3', '4', '6']
with PdfPages('param_hist.pdf') as pdf:
    for torsion in param_to_opt:
        torsion_name = torsion[0] + '_' + torsion[1] + '_' + torsion[2] + '_' + torsion[3]
        for n, m in enumerate(multiplicities):
            if n==1:
                plt.title(torsion)
            plt.subplot(3, 2, int(m))
            k = torsion_name + '_' + m + '_K'
            plt.hist(getattr(db, k)[:], bins=100, label=m)
            plt.legend()
        pdf.savefig()
        plt.show()
        plt.close()

# %%
import seaborn
db = sqlite_plus.load('butane_n.database')
plots.trace_no_phase('CG331_CG321_CG321_CG331', db, markersize=1.0, filename='trace_n_init_0.pdf')

# %%
import numpy as np
plt.plot(np.exp(sampler.log_sigma.trace[2000:]))
plt.title('sigma')
plt.xlabel('sampler')
plt.ylabel('KJ/mol')
plt.savefig('sigma_n.png')

# %%
plt.hist(sampler.trace('CG331_CG321_CG321_CG331_1_K')[50000:90000], bins=100)
plt.title('K_1')

# %%
plt.hist(db.trace('CG331_CG321_CG321_CG331_2_K')[40000:], bins=100)
plt.title('K_2')

# %%
plt.hist(sampler.trace('CG331_CG321_CG321_CG331_3_K')[60000:80000], bins=100)
plt.title('K_3')

# %%
plt.hist(db.trace('CG331_CG321_CG321_CG331_4_K')[2000:], bins=100)
plt.title('K_4')

# %%
plt.hist(sampler.trace('CG331_CG321_CG321_CG331_6_K')[2000:], bins=100)
plt.title('K_6')

# %%
plt.plot(sampler.BUTA1_offset.trace[:])

# %%
# Reload param and reparameterize
# reparameterize 
param_new = CharmmParameterSet('../data/charmm_ff/top_all36_cgenff.rtf', '../data/charmm_ff/par_all36_cgenff.prm')
# Turn off torsion
#param_new.dihedral_types[('CG331', 'CG321', 'CG321', 'CG331')][1].phi_k=0
#param_new.dihedral_types[('CG331', 'CG321', 'CG321', 'CG331')][0].phi_k=0

torsion = optimized_0.remove_nonoptimized()
torsion.compute_energy(param_new)
plt.plot(optimized.delta_energy, label='Fit')
plt.plot(optimized_0.delta_energy, label='CHARMM')
plt.plot(torsion.delta_energy, label='CHARMM torsion')
plt.title('Difference potential (QM-MM)')
plt.xlabel('Dihedral Angle')
plt.ylabel('Energy (KJ/mol)')
plt.legend()
plt.savefig('sample_n/diff_pot.png')
plt.savefig('sample_n/diff_pot.pdf')

#plt.plot(optimized.delta_energy, label='After fit')
#plt.plot(optimized_0.delta_energy, label='Diff')
plt.legend()
plt.title('Difference potential before and after fit')
plt.savefig('sample_n/diff_pot_fit.pdf')
plt.savefig('sample_n/diff_pot_fit.png')
